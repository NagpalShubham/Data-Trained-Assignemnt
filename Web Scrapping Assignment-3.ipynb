# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\dell\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio~=0.17 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dell\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dell\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"C:\Users\dell\Downloads\chromedriver.exe")

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
driver.get('https://www.amazon.in/')

# %%
userinput = input("enter product")
# Out:
# enter productguitar

# %%
# Finding search menu by xpath
Search=driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')
Search.clear()
# Feeding input specified by user to search menu through send keys
Search.send_keys(userinput)
# Finding Search button for clicking through xpath
Search_button=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
# Clicking search button
Search_button.click()

# %% [markdown]
# # Q2 In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
Brand =[]
Price =[]
Expected_delivery =[]

# %%
start = 0
end = 3
for pages in range(start,end):
    name_tag = driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-small s-title-instructions-style"]')
    for i in name_tag:
        Brand.append(i.text)
    next_button = driver.find_elements(By.XPATH,'//a[@href="/s?k=guitar&page=2&qid=1662104209&ref=sr_pg_1"]')
    time.sleep(3)

# %%
start = 0
end = 3
for pages in range(start,end):
    name_tag = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in name_tag:
        Price.append(i.text)
    Price.append('-')
    next_button = driver.find_elements(By.XPATH,'//a[@href="/s?k=guitar&page=2&qid=1662104209&ref=sr_pg_1"]')
    time.sleep(3)

# %%
start = 0
end = 3
for pages in range(start,end):
    name_tag = driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
    for i in name_tag:
        Expected_delivery.append(i.text)
    Expected_delivery.pop(pages)
    next_button = driver.find_elements(By.XPATH,'//a[@href="/s?k=guitar&page=2&qid=1662104209&ref=sr_pg_1"]')
    time.sleep(3)

# %%
df = pd.DataFrame({'Brand_name':Brand,'Price':Price,'Expected_delivery':Expected_delivery})
df
# Out:
#                                             Brand_name   Price  \
# 0    Sponsored\nKadence Frontier Series, Acoustic G...   5,299
# 1    Sponsored\nFestra 38C, 38 Inch Acoustic Guitar...   2,695
# 2    Sponsored\nExegi Enterprise 4 String Decor Gui...     999
# 3    Sponsored\nAcoustic Guitar, 39 Inch Cutaway, 0...   3,999
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   2,090
# ..                                                 ...     ...
# 187               Ibanez GSA60 Electric Guitar - Black   6,499
# 188  Sponsored\nGUITAR BRO - COMBO (Black Acoustic ...     975
# 189  Sponsored\nMustang 46 PCS Guitar Strings Chang...  10,920
# 190  Sponsored\nCort AD810 Dreadnought Acoustic Gui...   7,599
# 191  Sponsored\nVault EA40 41 inch Premium Solid Sp...       -
#
#           Expected_delivery
# 0       Sunday, September 4
# 1       Friday, September 9
# 2      Tuesday, September 6
# 3    Wednesday, September 7
# 4      Tuesday, September 6
# ..                      ...
# 187     Monday, September 5
# 188  Wednesday, September 7
# 189     Sunday, September 4
# 190   Thursday, September 8
# 191    Tuesday, September 6
#
# [192 rows x 3 columns]

# %% [markdown]
# # Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver.get('https://images.google.com/')

# %%
Search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')
# Clearing any previous input in search bar
Search.clear()
# Feeding input 'Fruits' in search bar
Search.send_keys('Fruits')
# Finding Search button for clicking through class name
Search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
# Clicking search button
Search_button.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")

# %%
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 100:
        break

# %%
driver.get('https://images.google.com/')
Search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')
# Clearing any previous input in search bar
Search.clear()
# Feeding input 'Fruits' in search bar
Search.send_keys('Cars')
# Finding Search button for clicking through class name
Search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
# Clicking search button
Search_button.click()

# %%
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break

# %%
driver.get('https://images.google.com/')
Search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')
# Clearing any previous input in search bar
Search.clear()
# Feeding input 'Fruits' in search bar
Search.send_keys('Machine Learning')
# Finding Search button for clicking through class name
Search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
# Clicking search button
Search_button.click()

# %%
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 100:
        break

# %% [markdown]
# Q4Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
url='http://www.flipkart.com/'
driver.get(url)
time.sleep(3)

try:
    login_window = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
    login_window.click()
except NoSuchElementException:
    print('Login Window is not present')
# Out:
# Login Window is not present

# %%
# Finding Search bar website by xpath
Search=driver.find_element(By.XPATH,'//div[@class="_3OO5Xc"]/input')
# Clearing any previous input in search bar
Search.clear()
# Feeding input 'Oneplus' in search bar
Search.send_keys('Iphone Mobile')
# Finding Search button for clicking through class name
Search_button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
# Clicking search button
Search_button.click()

# %%
# Making empty list to scrape data
Brand =[]
Smartphone =[]
Colour =[]
Storage_Rom =[]
Primary_camera=[]
Secondary_camera=[]
Display_size=[]
Display_resolution=[]
Processor =[]
Processor_cores=[]
Battery_capacity=[]
Price =[]

# %%
URL=[]
url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url:
    Href=i.get_attribute('href')
    URL.append(Href)

# %%
len(URL)
# Out:
# 24

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(3)
    
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name via Xpath
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Brand.append(brand.text.split()[0])
    
    except NoSuchElementException:
        Brand.append('-')
        
    # Extracting Smartphone Model via Xpath
    try:
        smartphone=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone.append(smartphone.text)
    
    except NoSuchElementException:
        Smartphone.append('-')
        
    # Extracting Colour via Xpath
    try:
        colour=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    
    except NoSuchElementException:
        Colour.append('-')
    
    # Extracting Storage Rom via Xpath
    try:
        Rom=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        Storage_Rom.append(Rom.text)
        
    except NoSuchElementException:
        Storage_Rom.append('Not Mention')
        
    # Extracting primary camera detail via Xpath
    try:
        primary_camera=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_camera.append(primary_camera.text)
    
    except NoSuchElementException:
        Primary_camera.append('Not Mention')
        
    # Extracting Secondary Camera detail via Xpath
    try:
        secondary_cam=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[5]/td[2]/ul/li')
        Secondary_camera.append(secondary_cam.text)
    
    except NoSuchElementException:
        Secondary_camera.append('Not Mention')
    
    # Extracting Display size via Xpath
    try:
        display=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_size.append(display.text)
    except NoSuchElementException:
        Display_size.append('-')
    
    # Extracting Display Resolution via Xpath
    try:
        resolution=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[2]/td[2]/ul/li')
        Display_resolution.append(resolution.text)
    except NoSuchElementException:
        Display_resolution.append('-')
    
    # Extracting processor detail via xpath
    try:
        processor=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table/tbody/tr[2]/td[2]/ul/li')
        Processor.append(processor.text)
    
    except NoSuchElementException:
        Processor.append('-')
        
    # Extracting Processor core via xpath
    try:
        core=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table/tbody/tr[3]/td[2]/ul/li')
        Processor_cores.append(core.text)
    except NoSuchElementException:
        Processor_cores.append('Not Mention')
    
    #Extracting Price via X path
    try:
        price=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Not Mention')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [06:06<00:00, 15.29s/it]

# %%
Iphone=pd.DataFrame({'Brand':Brand,'Smartphone':Smartphone,'Colour':Colour,'Price':Price,
                        'Storage Rom':Storage_Rom,'Primary Camera':Primary_camera,'Display Size':Display_size,
                        'Display Resolution':Display_resolution,'Processor':Processor,'Processor Cores':Processor_cores})
print('\033[1m'+'Flipkart Iphone Models :'+'\033[0m')
Iphone.head()
# Out:
# Flipkart Iphone Models :
#    Brand Smartphone     Colour    Price Storage Rom Primary Camera  \
# 0  APPLE          -          -  ₹41,999    iOS 14.2    Not Mention
# 1  APPLE          -          -  ₹54,900    iOS 14.2    Not Mention
# 2  APPLE  iPhone 13  Starlight  ₹69,999      128 GB    12MP + 12MP
# 3  APPLE          -          -  ₹41,999    iOS 14.2    Not Mention
# 4  APPLE  iPhone 13   Midnight  ₹69,999      128 GB    12MP + 12MP
#
#                                       Display Size  Display Resolution  \
# 0  iPhone, USB-C to Lightning Cable, Documentation           MHDC3HN/A
# 1  iPhone, USB-C to Lightning Cable, Documentation           MHDJ3HN/A
# 2                              15.49 cm (6.1 inch)  2532 x 1170 Pixels
# 3  iPhone, USB-C to Lightning Cable, Documentation           MHDA3HN/A
# 4                              15.49 cm (6.1 inch)  2532 x 1170 Pixels
#
#            Processor           Processor Cores
# 0  1792 x 828 Pixels  Liquid Retina HD Display
# 1  1792 x 828 Pixels  Liquid Retina HD Display
# 2    A15 Bionic Chip                 Hexa Core
# 3  1792 x 828 Pixels  Liquid Retina HD Display
# 4    A15 Bionic Chip                 Hexa Core

# %% [markdown]
# # 5 Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
url='https://www.google.co.in/maps'
driver.get(url)
time.sleep(3)

# %%
# Finding search menu by xpath
Search=driver.find_element(By.ID,"searchboxinput") 
# clearing any previous input in search bar
Search.clear()
# Feeding input specified by user to search menu through send keys
Search.send_keys('Delhi')
# Finding Search button for clicking through xpath
Search_button=driver.find_element(By.ID,"searchbox-searchbutton")  
# Clicking search button
Search_button.click()

# %%
current_url=driver.current_url
print('Current url :',current_url)
# Out:
# Current url : https://www.google.co.in/maps/place/Delhi/@21.125498,81.914063,5z/data=!4m5!3m4!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902

# %%
try:
    if "@" in current_url:
        location=current_url.split('@')[1].split(',*/data')[0].split(',')
        location
        print('Latitude of given Location:',location[0])
        print('Longitude of given Location:',location[1])
except:
    print('Location detail not found in url')
# Out:
# Latitude of given Location: 21.125498
# Longitude of given Location: 81.914063

# %% [markdown]
# # Q6 Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
url='https://www.trak.in'
driver.get(url)
time.sleep(3)

# %%
# Clicking funding deals button
Funding_deals=driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(Funding_deals)

# %%
# Making Empty list to scrap data
Date=[]
Startup=[]
Industry=[]
Sub_vertical=[]
City=[]
Investor=[]
Investment_type=[]
Amount=[]

# %%
from tqdm import tqdm
for i in tqdm(range(48,51)):
    # Extracting Date from table
    try:
        date=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
        for j in date:
            Date.append(j.text)
    except:
        Date.append('NA')
        
    # Extracting startup name via xpath
    try:
        startup=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
        for j in startup:
            Startup.append(j.text)
    except:
        Startup.append('NA')
    
    # Extracting Industry vertical via Xpath
    try:
        industry=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
        for j in industry:
            Industry.append(j.text)
    except:
        Industry.append('NA')
    
    # Extracting subvertical via xpath
    try:
        subvertical=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
        for j in subvertical:
            Sub_vertical.append(j.text)
    except:
        Sub_vertical.append('NA')
    
    # Extracting city/location via xpath
    try:
        city=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
        for j in city:
            City.append(j.text)
    except:
        City.append('NA')
        
    # Extracting Investor via xpath
    try:
        investor=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
        for j in investor:
            Investor.append(j.text)
    except:
        Investor.append('NA')
        
    # Extracting Investment type via xpath
    try:
        investment_type=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
        for j in investment_type:
            Investment_type.append(j.text)
    except:
        Investment_type.append('NA')
        
    # Extracting Amount type via xpath
    try:
        amount=driver.find_elements(BY.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
        for j in amount:
            Amount.append(j.text)
    except:
        Amount.append('NA')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:04<00:00,  1.66s/it]

# %%
Funding=pd.DataFrame({'Date':Date,'Startup Company':Startup,'Industry/Vertical':Industry,'Sub-Vertical':Sub_vertical,'City':City,
                        'Investor':Investor,'Investment Type':Investment_type})
print('\033[1m'+'Funding deals in second quarter (i.e. Jan 20 –march 20) :'+'\033[0m')
Funding
# Out:
# Funding deals in second quarter (i.e. Jan 20 –march 20) :
#           Date            Startup Company  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                           City  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed

# %% [raw]
# Q 7Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
url='https://www.digit.in'
driver.get(url)
time.sleep(3)

# %%
# Clicking on top 10 option button in menu bar
driver.find_element(By.XPATH,'//div[@class="menu"]/ul/li[4]/a').click()
time.sleep(3)

# Clicking on Laptop under table
driver.find_element(By.XPATH,'//div[@class="categoty_list"]/button[2]').click()

# Opening Best gaming laptops link
Gaming_lappy=driver.find_element(By.XPATH,'//div[@id="laptops"]/div[3]/a').get_attribute('href')
driver.get(Gaming_lappy)
time.sleep(3)

# %%
# Making Empty list for scraping data
Laptop_model =[]
OS =[]
Display = []
Processor =[]
Memory =[]
Weight =[]
Dimension =[]
Graphics_processor =[]
Price =[]

# %%
# Extracting Laptop model via Xpath
for i in range(0,11):
    laptop_model=driver.find_elements(By.XPATH,'//*[@id="toptenIdevent{}"]/a/h3'.format(i))
    for j in laptop_model:
       Laptop_model.append(j.text)

# %%
# Extracting OS on Laptop model via Xpath
os=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for j in os:
    OS.append(j.text)

# %%
# Extracting Display vertical via Xpath
display=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for j in display:
    Display.append(j.text)

# %%
# Extracting Processor via xpath
processor=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for j in processor:
    Processor.append(j.text)

# %%
# Extracting Memory via xpath
memory=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for j in memory:
    Memory.append(j.text)

# %%
# Extracting Laptop Weight via xpath
weight=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for j in weight:
    Weight.append(j.text)
# Extracting Dimension via xpath
dimension=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for j in dimension:
    Dimension.append(j.text)
# Extracting Graphics Processor type via xpath
graphics_processor=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[9]/td[3]')
for j in graphics_processor:
    Graphics_processor.append(j.text)
# Extracting Laptop Price type via xpath
price=driver.find_elements(By.XPATH,'//table[@id="summtable"]//tr//td[3]')
for j in price:
    Price.append(j.text)

# %%
#Make data frame
Gaming_Laptops=pd.DataFrame({"Laptop Model":Laptop_model,"Price":Price, "OS":OS,"Display":Display,"Memory":Memory,"Processor":Processor,
                 "Weight":Weight,"Dimension":Dimension})
print('\033[1m'+'Best Gaming Laptop :'+'\033[0m')
Gaming_Laptops
# Out:
# Best Gaming Laptop :
#                                     Laptop Model      Price  \
# 0                           MSI TITAN GT77-12UHS        N/A
# 1                               ALIENWARE X17 R2  ₹ 389,990
# 2          ACER PREDATOR TRITON 500 SE PT516-52S  ₹ 300,000
# 3                        OMEN BY HP (16-B1371TX)  ₹ 171,490
# 4  ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0  ₹ 172,999
# 5                     MSI DELTA 15 (A5EFK-083IN)  ₹ 188,990
# 6                        OMEN BY HP (16-C0141AX)  ₹ 129,899
# 7              LENOVO LEGION 5I PRO (82RF00MGIN)  ₹ 230,890
# 8  ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN  ₹ 144,990
# 9               LENOVO SLIM 7 GEN 6 (82K8002JIN)  ₹ 131,990
#
#                                                   OS  \
# 0   12th Gen Intel Core i9-12900HX 16 core processor
# 1  12th Gen Intel Core i9-12900HK 14 core process...
# 2  12th Gen Intel Core i7-12700H 14 core processo...
# 3  12th Gen Intel Core i7-12700H 14 core processo...
# 4                AMD Ryzen 9-5900HX 8 core processor
# 5  AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 6  AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 7  12th Gen Intel Core i7-12700H 14 core processo...
# 8  AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 9  Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
#
#                                            Display  \
# 0  17.3″ (3840 x 2160) screen, 120 Hz refresh rate
# 1    17.3″ (1920x1080) screen, 360 Hz refresh rate
# 2    16″ (2560 x 1600) screen, 240 Hz refresh rate
# 3                       16.1″ (2560 x 1440) screen
# 4  15.6″ (2560 x 1440) screen, 165 Hz refresh rate
# 5   15.6″ (1920 x 1080) screen, 240Hz refresh rate
# 6                       16.1″ (2560 x 1440) screen
# 7    16″ (2560 x 1600) screen, 165 Hz refresh rate
# 8   15.6″ (1920 x 1080) screen, 165Hz refresh rate
# 9                15.6″ screen, 165 Hz refresh rate
#
#                         Memory        Processor  \
# 0    64 GB DDR5 RAM & 2 TB SSD  Windows 11 Home
# 1    32 GB DDR5 RAM & 1 TB SSD  Windows 11 Home
# 2    32 GB DDR5 RAM & 2 TB SSD  Windows 11 Home
# 3     8 GB DDR5 RAM & 1 TB SSD  Windows 11 Home
# 4  16 GB DDR4 RAM & 512 GB SSD  Windows 11 Home
# 5    16 GB DDR4 RAM & 1 TB SSD  Windows 11 Home
# 6   16 GB DDR4 RAM & 1 TB NVMe  Windows 11 Home
# 7    16 GB DDR5 RAM & 1 TB SSD  Windows 11 Home
# 8  16 GB DDR4 RAM & 512 GB SSD  Windows 11 Home
# 9    16 GB DDR4 RAM & 1 TB SSD  Windows 11 Home
#
#                                               Weight  \
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 1  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti, Graphic...
# 2  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                            Dimension
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight
# 1  399.23 x 299.57 x 14.75 mm dimension & 3.02 kg...
# 2      358 x 262 x 19.9 mm dimension & 2.4 kg weight
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight
# 7  359.9 x 264.4 x 19.9 mm dimension & 2.5 kg weight
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight

# %% [markdown]
# # Q9Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Opening url in chrome browser
url="https://www.youtube.com"
driver.get(url)
time.sleep(3)

# %%
# Finding search menu by xpath
Search=driver.find_element(By.XPATH,'//input[@id="search"]') 
# Feeding input video name by user to search menu through send keys
Search.send_keys('I Hunted 100 People For $1,000,000 by mr beast')
# Finding Search button for clicking through xpath
Search_button=driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]/yt-icon')  
# Clicking search button
Search_button.click()
time.sleep(2)

# %%
# Clicking on video
link = driver.find_element(By.XPATH,"//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link.click()
time.sleep(3)

# %%
# Scrolling window using ScrollBy method from 0 pixel to 15000 pixel
driver.execute_script("window.scrollBy(0,1000000)","")

# %%
# Empty lists to scrap data
Comments = []
Comment_posted_ago = []
Timeline = []
Likes = []
No_of_Likes = []

# %%
#extracting comment on video
comment = driver.find_elements(By.ID,"content-text")
time.sleep(3)
from tqdm import tqdm
for i in tqdm(comment):
    if i.text is None:
        Comments.append("--")
    else:
        Comments.append(i.text)
time.sleep(2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.63it/s]

# %%
#Extracting time of commenting
timeline = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
time.sleep(3)
from tqdm import tqdm
for i in tqdm(timeline):
    if i.text is None:
        Timeline.append("-")
    else:
        Timeline.append(i.text)
for i in tqdm(range(0,len(Timeline),2)):
    Comment_posted_ago.append(Timeline[i])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<?, ?it/s]

# %%
# scrape the comment likes
like = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
time.sleep(3)

# %%
len(Comments),len(Comment_posted_ago),len(No_of_Likes)
# Out:
# (20, 10, 20)

# %%
YT=pd.DataFrame({})
YT['Comments']=Comments[:10]
YT['Comment Posted Ago']=Comment_posted_ago[:10]
YT['No. of Likes']=No_of_Likes[:10]
YT
# Out:
#                                             Comments Comment Posted Ago  \
# 0  What a life this man's living,while helping th...       11 hours ago
# 1  Mad respects to the employee who didn’t want t...       14 hours ago
# 2  For the guy who didn’t snitch out anyone when ...        9 hours ago
# 3  That guy at the candy store is a legend. Even ...          1 day ago
# 4  Props to the legends who refused to rat out co...        5 hours ago
# 5  The guy who sneaked under the stage and then m...         2 days ago
# 6  The guy at the candy store have all my respect...        4 hours ago
# 7  Every time you put this content out, I get mor...       16 hours ago
# 8  What a life this man's living, while helping t...       15 hours ago
# 9  This man literally born to create history hats...        4 hours ago
#
#   No. of Likes
# 0          932
# 1         1.1K
# 2          597
# 3          193
# 4          109
# 5          75K
# 6           2K
# 7           76
# 8           12
# 9          100

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Opening url in chrome browser
url="https://www.hostelworld.com/st/hostels/"
driver.get(url)
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3960/2910127860.py in <module>
#       1 # Opening url in chrome browser
#       2 url="https://www.hostelworld.com/st/hostels/"
# ----> 3 driver.get(url)
#       4 time.sleep(2)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     438         Loads a web page in the current browser session.
#     439         """
# --> 440         self.execute(Command.GET, {'url': url})
#     441
#     442     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# --> 428             self.error_handler.check_response(response)
#     429             response['value'] = self._unwrap_value(
#     430                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007878B3+2193587]
# 	Ordinal0 [0x00720681+1771137]
# 	Ordinal0 [0x006341A8+803240]
# 	Ordinal0 [0x0061D767+710503]
# 	Ordinal0 [0x00621142+725314]
# 	Ordinal0 [0x006255C9+742857]
# 	Ordinal0 [0x00635500+808192]
# 	Ordinal0 [0x0068D2C2+1168066]
# 	Ordinal0 [0x0067D5C6+1103302]
# 	Ordinal0 [0x006577E0+948192]
# 	Ordinal0 [0x006586E6+952038]
# 	GetHandleVerifier [0x00A30CB2+2738370]
# 	GetHandleVerifier [0x00A221B8+2678216]
# 	GetHandleVerifier [0x008117AA+512954]
# 	GetHandleVerifier [0x00810856+509030]
# 	Ordinal0 [0x0072743B+1799227]
# 	Ordinal0 [0x0072BB68+1817448]
# 	Ordinal0 [0x0072BC55+1817685]
# 	Ordinal0 [0x00735230+1856048]
# 	BaseThreadInitThunk [0x770AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x779E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x779E7A6E+238]

# %%
driver.find_element(By.XPATH,'//span[@class="pill-text"]').click()

# %%
#locating the location search bar
Search = driver.find_element(By.XPATH,'//input[@id="home-search-keywords"]')

# Sending input London in search bar
Search.send_keys("London")
time.sleep(1)

#select london
london = driver.find_element(By.XPATH,'//*[@id="top-search"]/div/div[1]/div[2]/ul/li[2]')
london.click()
time.sleep(2)

# do click on search button
Search_button = driver.find_element(By.XPATH,'//*[@id="top-search"]/div/div[2]/button')
Search_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3960/79099099.py in <module>
#       1 #locating the location search bar
# ----> 2 Search = driver.find_element(By.XPATH,'//input[@id="home-search-keywords"]')
#       3
#       4 # Sending input London in search bar
#       5 Search.send_keys("London")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     853             value = '[name="%s"]' % value
#     854
# --> 855         return self.execute(Command.FIND_ELEMENT, {
#     856             'using': by,
#     857             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# --> 428             self.error_handler.check_response(response)
#     429             response['value'] = self._unwrap_value(
#     430                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007878B3+2193587]
# 	Ordinal0 [0x00720681+1771137]
# 	Ordinal0 [0x006341A8+803240]
# 	Ordinal0 [0x0061D767+710503]
# 	Ordinal0 [0x00621142+725314]
# 	Ordinal0 [0x006255C9+742857]
# 	Ordinal0 [0x00635500+808192]
# 	Ordinal0 [0x0068D2C2+1168066]
# 	Ordinal0 [0x0067D5C6+1103302]
# 	Ordinal0 [0x006577E0+948192]
# 	Ordinal0 [0x006586E6+952038]
# 	GetHandleVerifier [0x00A30CB2+2738370]
# 	GetHandleVerifier [0x00A221B8+2678216]
# 	GetHandleVerifier [0x008117AA+512954]
# 	GetHandleVerifier [0x00810856+509030]
# 	Ordinal0 [0x0072743B+1799227]
# 	Ordinal0 [0x0072BB68+1817448]
# 	Ordinal0 [0x0072BC55+1817685]
# 	Ordinal0 [0x00735230+1856048]
# 	BaseThreadInitThunk [0x770AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x779E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x779E7A6E+238]
